# %% [markdown]
# # VISUALIZACIÓN DE RESULTADOS

# %% [markdown]
# # Carga de las bibliotecas y los datos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import plotly.express as px
from IPython.display import Image

# %%
df = pd.read_csv("../Data/escalados.csv", sep=',', index_col='CUST_ID')
labels = pd.read_csv("../Data/scaled_PCA_labels.csv", sep=',', index_col='CUST_ID')

# %% [markdown]
# # Visualización de los clusters con spider plots

# %%
def plot_spider_by_method_plotly(df, labels_df):
    methods = labels_df.columns
    
    for method in methods:
        data_by_cluster = df.groupby(labels_df[method]).mean()
        
        melted_data = (
            data_by_cluster.reset_index()
            .melt(id_vars=labels_df[method].name, var_name='Feature', value_name='Value'))
        melted_data = melted_data[melted_data[labels_df[method].name] != -1]
        
        
        fig = px.line_polar(
            melted_data,
            r="Value",
            theta="Feature",
            color=labels_df[method].name,
            line_close=True,
            color_discrete_sequence=px.colors.qualitative.G10,
            title=method,
            template="plotly_white")
        fig.update_traces(fill='toself', opacity=0.7)
        fig.write_image("spiderplot.png")
        Image("spiderplot.png")
        fig.show()
        
plot_spider_by_method_plotly(df, labels)
# Out:
# <div>                            <div id="33a615f6-92e7-4f73-8bae-f7eefbf54524" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33a615f6-92e7-4f73-8bae-f7eefbf54524")) {                    Plotly.newPlot(                        "33a615f6-92e7-4f73-8bae-f7eefbf54524",                        [{"hovertemplate":"K-means clusters=0\u003cbr\u003eValue=%{r}\u003cbr\u003eFeature=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","line":{"color":"#3366CC","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0","r":[-0.36790873005303865,-0.17803040658372477,-0.2339448971737284,-0.20574883431839855,-0.17506013585037625,-0.3105813941769025,-0.06196379027446118,-0.23569921710980232,-0.04666518977353495,-0.3342842974656711,-0.29939649849756533,-0.24346925262898564,-0.3381102191736801,-0.28535640046893096,-0.14567478993691643,0.005434788834038659,-0.028541711823334263,-0.36790873005303865],"showlegend":true,"subplot":"polar","theta":["BALANCE","BALANCE_FREQUENCY","PURCHASES","ONEOFF_PURCHASES","INSTALLMENTS_PURCHASES","CASH_ADVANCE","PURCHASES_FREQUENCY","ONEOFF_PURCHASES_FREQUENCY","PURCHASES_INSTALLMENTS_FREQUENCY","CASH_ADVANCE_FREQUENCY","CASH_ADVANCE_TRX","PURCHASES_TRX","CREDIT_LIMIT","PAYMENTS","MINIMUM_PAYMENTS","PRC_FULL_PAYMENT","TENURE","BALANCE"],"type":"scatterpolar","fill":"toself","opacity":0.7},{"hovertemplate":"K-means clusters=1\u003cbr\u003eValue=%{r}\u003cbr\u003eFeature=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","line":{"color":"#DC3912","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1","r":[0.31694020031494763,0.4378610347957447,1.5268903219610848,1.2812382714767243,1.2560323894869232,-0.24773911476272584,1.1383223362765453,1.5547177576886169,0.9488341135032633,-0.35951568021967195,-0.2513106206784677,1.6707134178291978,0.8916583615206273,0.8329003018478095,0.1509822555572872,0.5021208053015239,0.30292177146667015,0.31694020031494763],"showlegend":true,"subplot":"polar","theta":["BALANCE","BALANCE_FREQUENCY","PURCHASES","ONEOFF_PURCHASES","INSTALLMENTS_PURCHASES","CASH_ADVANCE","PURCHASES_FREQUENCY","ONEOFF_PURCHASES_FREQUENCY","PURCHASES_INSTALLMENTS_FREQUENCY","CASH_ADVANCE_FREQUENCY","CASH_ADVANCE_TRX","PURCHASES_TRX","CREDIT_LIMIT","PAYMENTS","MINIMUM_PAYMENTS","PRC_FULL_PAYMENT","TENURE","BALANCE"],"type":"scatterpolar","fill":"toself","opacity":0.7},{"hovertemplate":"K-means clusters=2\u003cbr\u003eValue=%{r}\u003cbr\u003eFeature=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2","line":{"color":"#FF9900","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2","r":[1.1575133576781647,0.33941804359181366,-0.2921276032702735,-0.20911293066310566,-0.3066208482851408,1.3768972859298245,-0.6467104774824071,-0.3070233205244842,-0.5580684915828075,1.5540241595600781,1.3370032524717603,-0.36736998072370297,0.5974490919482858,0.44235438024283685,0.3915204295852058,-0.41025877301309593,-0.12612405125327922,1.1575133576781647],"showlegend":true,"subplot":"polar","theta":["BALANCE","BALANCE_FREQUENCY","PURCHASES","ONEOFF_PURCHASES","INSTALLMENTS_PURCHASES","CASH_ADVANCE","PURCHASES_FREQUENCY","ONEOFF_PURCHASES_FREQUENCY","PURCHASES_INSTALLMENTS_FREQUENCY","CASH_ADVANCE_FREQUENCY","CASH_ADVANCE_TRX","PURCHASES_TRX","CREDIT_LIMIT","PAYMENTS","MINIMUM_PAYMENTS","PRC_FULL_PAYMENT","TENURE","BALANCE"],"type":"scatterpolar","fill":"toself","opacity":0.7}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10 ...
# <div>                            <div id="5f21ac27-be89-413c-a5d1-323fe84d9114" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f21ac27-be89-413c-a5d1-323fe84d9114")) {                    Plotly.newPlot(                        "5f21ac27-be89-413c-a5d1-323fe84d9114",                        [{"hovertemplate":"DBSCAN clusters=0\u003cbr\u003eValue=%{r}\u003cbr\u003eFeature=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","line":{"color":"#3366CC","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0
u003cbr\u003eValue=%{r}\u003cbr\u003eFeature=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2","line":{"color":"#DC3912","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2","r":[1.4048253444377734,0.4285836503868064,-0.20343541042894622,-0.1429947997124414,-0.2183985627752872,1.5286936842834473,-0.49944194831816474,-0.18738037803909788,-0.41758843602244217,1.676807887912989,1.593624554970419,-0.22726848872827898,0.8229342258498981,0.6959096917747057,0.2956296097459998,-0.39618355912074993,0.22824895745183513,1.4048253444377734],"showlegend":true,"subplot":"polar","theta":["BALANCE","BALANCE_FREQUENCY","PURCHASES","ONEOFF_PURCHASES","INSTALLMENTS_PURCHASES","CASH_ADVANCE","PURCHASES_FREQUENCY","ONEOFF_PURCHASES_FREQUENCY","PURCHASES_INSTALLMENTS_FREQUENCY","CASH_ADVANCE_FREQUENCY","CASH_ADVANCE_TRX","PURCHASES_TRX","CREDIT_LIMIT","PAYMENTS","MINIMUM_PAYMENTS","PRC_FULL_PAYMENT","TENURE","BALANCE"],"type":"scatterpolar","fill":"toself","opacity":0.7},{"hovertemplate":"Hierarchical clustering 3 clusters=3\u003cbr\u003eValue=%{r}\u003cbr\u003eFeature=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3","line":{"color":"#FF9900","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"3","r":[-0.2875348807759055,-0.1733491636302299,-0.23765862345238792,-0.22980718453425036,-0.13969879644089944,-0.20777104682868813,-0.1451460913288056,-0.36257909292665347,-0.038420831525448396,-0.20513898575047035,-0.21486563054838556,-0.2492670817516161,-0.2928814170997792,-0.2581031326180658,-0.06490754968539046,-0.03541424737855967,-0.11074933059131739,-0.2875348807759055],"showlegend":true,"subplot":"polar","theta":["BALANCE","BALANCE_FREQUENCY","PURCHASES","ONEOFF_PURCHASES","INSTALLMENTS_PURCHASES","CASH_ADVANCE","PURCHASES_FREQUENCY","ONEOFF_PURCHASES_FREQUENCY","PURCHASES_INSTALLMENTS_FREQUENCY","CASH_ADVANCE_FREQUENCY","CASH_ADVANCE_TRX","PURCHASES_TRX","CREDIT_LIMIT","PAYMENTS","MINIMUM_PAYMENTS","PRC_FULL_PAYMENT","TENURE","BALANCE"],"type":"scatterpolar","fill":"toself","opacity":0.7}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width ...

# %% [markdown]
# # Comparación de algoritmos

# %% [markdown]
# **K-means:** Produjo tres clusters bien definidos con un coeficiente de silueta de 0.26, siendo una opción robusta para identificar grupos de clientes.
#
# **DBSCAN:** Identificó cuatro clusters, aunque con mayor solapamiento y menor calidad en la segmentación (coeficiente de silueta de 0.19).
#
# **Clustering jerárquico:** Obtuvo el mayor coeficiente de silueta (0.27) con dos clusters, mientras que al dividirse en tres clusters los resultados fueron muy similares a los obtenidos con K-means.

# %% [markdown]
# # Clusters identificados

# %% [markdown]
# K-means y el clustering jerárquico para tres clusters produjeron tres segmentos de clientes muy similares:
#
# **Clientes promedio:** Con comportamiento cercano a la media, sin características extremas.
#
# **Clientes VIP:** Con alta frecuencia de compras y un gasto elevado, posiblemente un grupo objetivo para promociones premium.
#
# **Clientes crediticios:** Caracterizados por el uso frecuente de avances en efectivo, pagos mínimos recurrentes y límites de crédito altos, un perfil que podría requerir estrategias para mitigar el riesgo crediticio.

# %% [markdown]
# # Recomendaciones y perspectivas

# %% [markdown]
# La elección entre usar dos o tres clusters dependerá de las necesidades específicas del negocio. Por ejemplo, si el objetivo es identificar riesgos crediticios, el cluster "deudor" es clave; mientras que para maximizar ingresos, el cluster "derrochador" es el foco principal.
#
# Los coeficientes de silueta obtenidos son moderados, lo que indica que los clusters podrían no estar perfectamente separados. Esto podría mejorarse con más variables o técnicas avanzadas de preprocesamiento.
#
# Incorporar variables socioeconómicas permitiría un análisis más profundo.
